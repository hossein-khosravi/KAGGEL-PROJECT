# %%
#import libraries
import numpy as np
import matplotlib.pyplot as plt
import cv2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7156\3316053216.py in <module>
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
# ----> 4 import cv2
#
# ModuleNotFoundError: No module named 'cv2'

# %%
A = np.ones((6, 6))
A[:,:2] = A[:,:2]*2
A[:,2:4] = A[:,2:4]*3
A[:,4:] = A[:,4:]*4

print(A)
# Out:
# [[2. 2. 3. 3. 4. 4.]
#  [2. 2. 3. 3. 4. 4.]
#  [2. 2. 3. 3. 4. 4.]
#  [2. 2. 3. 3. 4. 4.]
#  [2. 2. 3. 3. 4. 4.]
#  [2. 2. 3. 3. 4. 4.]]

# %%
our_map = 'hot'
#our_map = 'gray'

# %%
U, S, VT = np.linalg.svd(A)
S = np.diag(S)

# %%
def draw_svd(A,U, S, VT, our_map):
  plt.subplot(221 )
  plt.title('Original matrix')
  plt.imshow(A, cmap =our_map)
  plt.axis('off')
  plt.subplot(222)
  plt.title('U  matrix')
  plt.imshow(U, cmap =our_map)
  plt.axis('off')
  plt.subplot(223)
  plt.title('Sigma matrix')
  plt.imshow(S, cmap =our_map)
  plt.axis('off')
  plt.subplot(224)
  plt.title('V matrix')
  plt.imshow(VT, cmap =our_map)
  plt.axis('off')

# %%
def truncate_u_v(S, U, VT):
  threshold = 0.001
  s = np.diag(S)
  index = s < threshold

  U[:,index] = 0
  VT[index,:]=0
  return U, VT

# %%
U, VT = truncate_u_v(S, U, VT)
draw_svd(A, U, S, VT, our_map)

# %%
r = 1
A0_r = np.matmul(U[:,:r] , S[:r,:r]) 
A0_r = np.matmul (A0_r , VT[:r,:])
plt.imshow(A0_r, cmap =  our_map)
plt.axis('off')
# Out:
# (-0.5, 5.5, 5.5, -0.5)

# %%
A = [[1, 0], [1, 1]]
U, S, VT = np.linalg.svd(A)
S = np.diag(S)

print(f"U {U}\nS {S}\nVT {VT}")
# Out:
# U [[-0.52573111 -0.85065081]
#  [-0.85065081  0.52573111]]
# S [[1.61803399 0.        ]
#  [0.         0.61803399]]
# VT [[-0.85065081 -0.52573111]
#  [-0.52573111  0.85065081]]

# %%
from sklearn.datasets import fetch_olivetti_faces
face = fetch_olivetti_faces()

X = face.data
# The images are of size 64 x 64
X.shape
# Out:
# downloading Olivetti faces from https://ndownloader.figshare.com/files/5976027 to C:\Users\hossein.kh\scikit_learn_data
# (400, 4096)

# %%
C:\Users\hossein.kh\scikit_learn_data
# Out:
#   File "C:\Users\hossein.kh\AppData\Local\Temp\ipykernel_7156\2780751332.py", line 1
#     C:\Users\hossein.kh\scikit_learn_data
#        ^
# SyntaxError: unexpected character after line continuation character

# %%
faces = X[0,:].reshape((64,64))

# %%
# we decompose the image of a face
U, S, VT = np.linalg.svd(faces)
S = np.diag(S)
faces = faces.astype('float')
#U, VT = truncate_u_v(S, U, VT)
draw_svd(faces, U, S, VT, 'gray')

# %%
diag_elem = np.diag(S)
plt.stem(diag_elem[1:])
# Out:
# <StemContainer object of 3 artists>

# %%
  for r in range(1, 40):
    img_r = np.matmul(U[:,:r] , S[:r,:r]) 
    img_r = np.matmul (img_r , VT[:r,:])

    plt.title(f"A rank-{r} approximation")
    plt.imshow(img_r, cmap = 'gray')
    filename = "image_" + str(r).zfill(3) + ".jpg"
    plt.axis('off')
    plt.savefig(filename)
